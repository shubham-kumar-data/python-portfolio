# %% [markdown]
# # Day - 4
# # Control flow statements

# %% [markdown]
# # If Condition

# %% [markdown]
# Write a program to calculate result of a student in subjects ( Maths, Science, Social, English, History )

# %%
x = input('Enter the name of the Student :')
a = int(input('Enter the marks scored in Maths : '))
b = int(input('Enter the marks scored in Science :'))
c = int(input('Enter the marks scored in Social :'))
d = int(input('Enter the marks scored in English :'))
e = int(input('Enter the marks scored in History :'))
f = ((a+b+c+d+e)/500)*100
print('The percent scored by student is :',f)
# Out:
# Enter the name of the Student : Shubham Kumar
# Enter the marks scored in Maths :  48
# Enter the marks scored in Science : 68
# Enter the marks scored in Social : 79
# Enter the marks scored in English : 25
# Enter the marks scored in History : 48
# The percent scored by student is : 53.6

# %% [markdown]
# Write a program using If statement to assing grades to the student

# %%
a = int(input('Enter the percentage scored by the student : '))
if a>= 90:
    print('A Grade')
if a>=75 and a<90:
    print('B Grade')
if a>65 and a<75:
    print('C Grade')
# Out:
# Enter the percentage scored by the student :  85
# B Grade

# %% [markdown]
# # If Else statement

# %% [markdown]
# Write a program to display 'hello' if the number entered by the user is a multiple of 5 else print 'bye'

# %%
x = int(input(' Enter the number : ' ))
if x%5==0:
       print('Hello')
else:
       print('Bye')
# Out:
#  Enter the number :  545
# Hello

# %% [markdown]
# Write a program to tell wether a number is positive or negative number

# %%
x = int(input( 'Enter the number : '))
if x>=0:
        print( 'This number is positive')
else:
        print('This number is negative')
# Out:
# Enter the number :  0
# This number is positive

# %% [markdown]
# # If- Elif - Else Statement

# %% [markdown]
# Write a program accepting the country from the user and printing its captial
# 1.America - Washington, D.C.
# 2.United Kingdom - London
# 3.Australia - Canberra
# 4.Germany - berlin
# 5.Canada - Ottawa
# 6.Other -Record not found

# %%
country = input ('Enter the name of the country you wish to check the captial :')
if country=='America':
    print('The captial of America is Washington, D.C.')
elif country=='United Kingdom':
    print('The captial of Untied Kingdom is London')
elif country=='Australia':
    print('The captial of Australia is Canberra')
elif country=='Germany':
    print('The captial of Germany is Berlin')
elif country=='Canada':
    print('The captial of Canada is ottawa')
else:
    print('No record found')
# Out:
# Enter the name of the country you wish to check the captial : America
# The captial of America is Washington, D.C.
