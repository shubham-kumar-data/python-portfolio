# %% [markdown]
# # Day 7
# # creating  string in python

# %%
a = "Hello this is string"
print(a)
# Out:
# Hello this is string

# %%
b = 'This is the learning day 7 and I am learning string today'
print(b)
print(type(b))
# Out:
# This is the learning day 7 and I am learning string today
# <class 'str'>

# %% [markdown]
# # Multiline String

# %%
b = 'Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.' 
print (b)
# Out:
# Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.

# %%
b = """Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation, 
an extensive ("batteries-included") standard library, and garbage collection. 
Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing."""

print (b)
# Out:
# Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,
# an extensive ("batteries-included") standard library, and garbage collection.
# Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.

# %% [markdown]
# # Indexing of string

# %%
a = "Hello students"
print (a[11])
# Out:
# n

# %%
a = "Hello students"
print (a[-2])
# Out:
# t

# %%
a = "How is your studies going on"
print ( a [12])
# Out:
# s

# %%
a= "How is your studies going on"
print ( a [-12])
# Out:
# i

# %%
x = "Hello students how are you?"
print(x[0:5])
# Out:
# Hello

# %%
x = "Hello students how are you?"
print(x[6:18])
# Out:
# students how

# %%
x = "Hello students how are you?"
print(x[0:20:2])
# Out:
# Hlosuet o

# %%
x = "Hello students how are you?"
print(x[::-1])
# Out:
# ?uoy era woh stneduts olleH

# %% [markdown]
# # finding lenght of string

# %%
a = 'This is the day 7 of python learning'
print(len(x))
# Out:
# 27

# %%
b = 'Hello World'
print(b)
print(len(b))
# Out:
# Hello World
# 11

# %% [markdown]
# # Upper method

# %%
x = "hello how are you"
print(x.upper())
# Out:
# HELLO HOW ARE YOU

# %% [markdown]
# # lower method

# %%
x = "Hello HOW ARE YOU"
print(x.lower())
# Out:
# hello how are you

# %% [markdown]
# # Replace Function

# %%
a = "Hello how are you"
print(a.replace("Hello","bye"))
# Out:
# bye how are you

# %%
a = "Hello how are you"
print(a.replace("H","s"))
# Out:
# sello how are you

# %%
a = "Hello world"
print(a)
print(a.replace("world","student"))
# Out:
# Hello world
# Hello student

# %% [markdown]
# # Find Method

# %%
a = "python is great"
b =  a.find('t') 
print(b)
# Out:
# 2
